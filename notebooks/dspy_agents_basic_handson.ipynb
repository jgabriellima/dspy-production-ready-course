# %% [markdown]
# # 🚀 DSPy ReAct Agents - Fundamentos (Abordagem Hands-On)
#
# **Versão:** 1.0 - Basic Hands-On
# **Nível:** Iniciante
# **Tempo estimado:** 15-20 minutos
# **Abordagem:** Fazer → Testar → Entender
#
# ---
#
# ## 📋 Sobre este Notebook
#
# Este notebook oferece uma **introdução prática e rápida** aos agentes ReAct em DSPy. Você vai:
#
# 🎯 Criar um agente funcionando em **5 minutos**
# ⚡ Testar com casos reais **imediatamente**
# 🔍 Entender **como funciona** depois de ver resultados
# 🧪 Experimentar e **modificar** o código livremente
# 💡 Resolver problemas comuns de **debugging**
#
# ### 🎯 Pré-requisitos
#
# - Python básico (funções, classes)
# - Vontade de experimentar e aprender fazendo!
# - Jupyter Notebooks
#
# ### 📚 Navegação entre Notebooks
#
# **Série DSPy ReAct Agents:**
#
# 1. [Fundamentos (Linear)](dspy_agents_basic_linear.ipynb) - Mesmos conceitos, abordagem teórica
# 2. **→ Você está aqui:** Fundamentos (Hands-On)
# 3. [Otimização Avançada (Linear)](dspy_agents_advanced_linear.ipynb) - Melhorando performance
# 4. [Otimização Avançada (Hands-On)](dspy_agents_advanced_handson.ipynb) - Otimização na prática
#
# ---
#
# ## ⚡ Quick Start: Seu Primeiro Agente em 5 Minutos!
#
# Neste notebook, vamos **fazer primeiro, explicar depois**.
#
# Vamos criar um **agente de atendimento ao cliente** que pode:
# - ✈️ Buscar e reservar voos
# - 👤 Consultar perfis de usuários
# - 🎫 Gerenciar tickets de suporte
#
# **Filosofia:** Ver funcionando → Testar → Entender → Experimentar
#
# Pronto? Vamos direto ao código!
