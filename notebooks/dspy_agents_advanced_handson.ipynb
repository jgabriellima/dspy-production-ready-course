# %% [markdown]
# # ⚡ DSPy ReAct Agents - Otimização Avançada (Abordagem Hands-On)
#
# **Versão:** 1.0 - Advanced Hands-On
# **Nível:** Intermediário/Avançado
# **Tempo estimado:** 30-45 minutos
# **Abordagem:** Otimizar agora → Ver resultados → Entender técnica
#
# ---
#
# ## 📋 Sobre este Notebook
#
# Este notebook oferece uma **abordagem prática e direta** para otimizar agentes ReAct. Você vai:
#
# ⚡ **Otimizar** seu agente em minutos
# 📊 Ver **melhorias dramáticas** imediatamente
# 🔍 Entender **o que aconteceu** depois dos resultados
# 🧪 **Experimentar** com diferentes técnicas
# 🚀 **Deployar** em produção rapidamente
#
# ### 🎯 Pré-requisitos
#
# **Essencial:**
# - Um agente ReAct funcional (dos notebooks básicos)
# - Python intermediário
# - Vontade de experimentar!
#
# **Recomendado:**
# - Noções de métricas de ML
# - Paciência (otimização pode demorar alguns minutos)
#
# ### 📚 Navegação entre Notebooks
#
# **Série DSPy ReAct Agents:**
#
# 1. [Fundamentos (Linear)](dspy_agents_basic_linear.ipynb) - Conceitos básicos primeiro
# 2. [Fundamentos (Hands-On)](dspy_agents_basic_handson.ipynb) - Prática básica primeiro
# 3. [Otimização Avançada (Linear)](dspy_agents_advanced_linear.ipynb) - Mesma otimização, teoria primeiro
# 4. **→ Você está aqui:** Otimização Avançada (Hands-On)
#
# ---
#
# ## 🎯 O Problema
#
# Seu agente básico funciona, mas tem problemas:
#
# ```
# ❌ "Busque voos baratos de SFO para JFK"
#    → Agente usa ferramenta errada
#    → Ou precisa de muitas tentativas
#    → Ou dá resposta genérica
#
# ❌ Inconsistente entre execuções
# ❌ Lento (muitas iterações)
# ❌ Falha em casos complexos
# ```
#
# ## 💡 A Solução
#
# **Vamos otimizar AGORA e ver a mágica acontecer!**
#
# ```
# ✅ "Busque voos baratos de SFO para JFK"
#    → Agente escolhe ferramentas corretas
#    → Responde rápido e precisamente
#    → Resultado consistente sempre
#
# ✅ +25% precisão
# ✅ +30% eficiência
# ✅ Pronto para produção
# ```
#
# **Filosofia:** Wow effect primeiro → Entender depois → Experimentar livremente
#
# Vamos lá!
